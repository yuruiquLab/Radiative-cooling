# %%
import numpy as np
import matplotlib.pyplot as plt

import tidy3d as td
import tidy3d.web as web

# %%
# Define Paramters
# radius and location of the sphere
radius_Al2O3 = 0.25
radius_SiO2 = 4 # exp is 6um
box_size_xy = 10
box_size_z = 30

vol_Al2O3 = 4/3 * np.pi * np.power(radius_Al2O3,3)
vol_SiO2 = 4/3 * np.pi * np.power(radius_SiO2,3)
vol_box = box_size_xy * box_size_xy * box_size_z
num_Al2O3 = int(np.floor(0.2 * vol_box / vol_Al2O3))   # 20% of volumn is Al2O3
num_SiO2 = int(np.floor(0.3 * vol_box / vol_SiO2))   # 30% of volumn is SiO2
print('num_Al2O3',num_Al2O3)
print('num_SiO2',num_SiO2)

center = [0, 0, 0]

# permittivity of the Al2O3 sphere 
eps_Al2O3 = 3.0625
eps_SiO2 = 2.1316

# free space central wavelength
wl_start = 0.3  # wavelength
wl_end = 2.5  # wavelength
freq_start = td.C_0 / wl_end
freq_end = td.C_0 / wl_start

freqs = np.linspace(freq_start, freq_end, 100)  # freqeucny range of the simulation
freq0 = (freq_start + freq_end)/2  # central frequency
freqw = freq_end - freq_start  # width of the frequency range
print('freq0:',freq0)

lda0 = wl_start
print('lda0:',lda0)

# distance between the surface of the sphere and the start of the PML layers along each cartesian direction
buffer_PML = 2 * wl_end
buffer_source = 1 * wl_end

# Define material properties
air = td.Medium(permittivity=1)
Al2O3 = td.Medium(permittivity=eps_Al2O3)
SiO2 = td.Medium(permittivity=eps_SiO2)

# resolution control
min_steps_per_wvl = 20

# set the domain size in x, y, and z
domain_size_xy = box_size_xy 
domain_size_z = buffer_PML + box_size_z + buffer_PML

# construct simulation size array
sim_size = (domain_size_xy, domain_size_xy, domain_size_z)
print('sim_size:',sim_size)
# Out:
# num_Al2O3 9167
# num_SiO2 3
# freq0: 559612588266666.7
# lda0: 0.3
# sim_size: (10, 10, 40.0)

# %%
# Create random structures
SiO2_geometry = []
Al2O3_geometry = []
geometry = []
for i in range(num_SiO2):
    position_xy = (box_size_xy - 2*radius_SiO2) * (np.random.rand(2) - 0.5) 
    position_z = (box_size_z - 2*radius_SiO2) * (np.random.rand(1) - 0.5) 
    position = [position_xy[0],position_xy[1],position_z]
    sphere = td.Sphere(center=position, radius=radius_SiO2)
    SiO2_geometry.append(sphere)
    
geometry.append(td.Structure(geometry=td.GeometryGroup(geometries=SiO2_geometry), medium=SiO2))
   
for i in range(num_Al2O3):
    position_xy = (box_size_xy - 2*radius_Al2O3) * (np.random.rand(2) - 0.5) 
    position_z = (box_size_z - 2*radius_Al2O3) * (np.random.rand(1) - 0.5)
    position = [position_xy[0],position_xy[1],position_z]
    sphere = td.Sphere(center=position, radius=radius_Al2O3)
    Al2O3_geometry.append(sphere)

geometry.append(td.Structure(geometry=td.GeometryGroup(geometries=Al2O3_geometry), medium=Al2O3))
geometry = tuple(geometry)
print('Geometry Finish')
# Out:
# Geometry Finish

# %%
# add a plane wave source
plane_wave = td.PlaneWave(
    source_time=td.GaussianPulse(freq0=freq0, fwidth=0.5 * freqw),
    size=(td.inf, td.inf, 0),
    center=(0, 0, box_size_z/2 + buffer_source),
    direction="-",
    pol_angle=0,
)

# add a flux monitor to detect transmission
monitor_t = td.FluxMonitor(
    center=[0, 0, -box_size_z/2 - (buffer_source+buffer_PML)/2], size=[td.inf, td.inf, 0], freqs=freqs, name="T"
)

# add a flux monitor to detect reflection
monitor_r = td.FluxMonitor(
    center=[0, 0, box_size_z/2 + (buffer_source+buffer_PML)/2], size=[td.inf, td.inf, 0], freqs=freqs, name="R"
)

# add a field monitor to see the field profile at the absorption peak frequency
monitor_field = td.FieldMonitor(
    center=[0, 0, 0], size=[td.inf, 0, box_size_z], freqs=[freq0], name="field"
)

print('Source and Monitor setup Finish')
# Out:
# Source and Monitor setup Finish

# %%
run_time = 1e-11  # simulation run time

# set up simulation
sim = td.Simulation(
    size=sim_size,
#     grid_spec=td.GridSpec.auto(min_steps_per_wvl=min_steps_per_wvl, wavelength=lda0), # Non uniform grip
    grid_spec=td.GridSpec.uniform(dl =lda0/10),
    structures=geometry,
    sources=[plane_wave],
    monitors=[monitor_t, monitor_r, monitor_field],
    run_time=run_time,
    boundary_spec=td.BoundarySpec(
        x=td.Boundary.periodic(), y=td.Boundary.periodic(), z=td.Boundary.pml()
    ), 
#     boundary_spec=td.BoundarySpec.all_sides(boundary=td.PML()),  # PML boundary
)  # symmetry can be used to greatly reduce the computational cost

print('Simulation setup Finish')
# Out:
# Simulation setup Finish

# %%
# Visualize source
plane_wave.source_time.plot(np.linspace(0, run_time/10, 1001))
plt.show()

plane_wave.source_time.plot_spectrum(
    times=np.linspace(0, run_time/10, 2000), val="abs"
)
plt.show()

# %%
cfig, ax = plt.subplots(1, 2, figsize=(7, 3))
sim.plot(y=0, ax=ax[0])
sim.plot(z=0.1, freq=freq0, ax=ax[1])
plt.show()

print('Visualize Source Finish')
# Out:
# Visualize Source Finish

# %%
task_id = web.upload(sim, task_name="Simulation")
print("Max flex unit cost: ", web.estimate_cost(task_id))
# Out:
# [19:08:50] Created task 'Simulation' with task_id 'fdve-80e7b778-65e4-4557-8a2f-57abaa90565fv1'.      ]8;id=33970;file://C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=7576;file://C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\tidy3d\web\webapi.py#186\186]8;;\
#            View task using web UI at                                                                  ]8;id=844863;file://C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=700422;file://C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\tidy3d\web\webapi.py#188\188]8;;\
#            ]8;id=200016;https://tidy3d.simulation.cloud/workbench?taskId=fdve-80e7b778-65e4-4557-8a2f-57abaa90565fv1\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=994461;https://tidy3d.simulation.cloud/workbench?taskId=fdve-80e7b778-65e4-4557-8a2f-57abaa90565fv1\taskId]8;;\]8;id=200016;https://tidy3d.simulation.cloud/workbench?taskId=fdve-80e7b778-65e4-4557-8a2f-57abaa90565fv1\=]8;;\]8;id=658715;https://tidy3d.simulation.cloud/workbench?taskId=fdve-80e7b778-65e4-4557-8a2f-57abaa90565fv1\fdve]8;;\]8;id=200016;https://tidy3d.simulation.cloud/workbench?taskId=fdve-80e7b778-65e4-4557-8a2f-57abaa90565fv1\-80e7b778-65e4-4557-8a2f-57abaa90565]8;;\
#            ]8;id=200016;https://tidy3d.simulation.cloud/workbench?taskId=fdve-80e7b778-65e4-4557-8a2f-57abaa90565fv1\fv1']8;;\.
# C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\rich\live.py:229: UserWarning: install "ipywidgets"
# for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Max flex unit cost:  9.026754053476228

# %%
web.start(task_id)
web.monitor(task_id, verbose=True)

import time
time.sleep(4)
print("Billed flex unit cost: ", web.real_cost(task_id))

sim_data = web.load(task_id, path="data/cooling.hdf5")

# Show the output of the log file
print(sim_data.log)


# sim_data = sim.dict_from_hdf5(fname='data/cooling.hdf5')
# # print(sim_data)

# R = sim_data["R"].flux
# print(R)
# Out:
# [19:08:57] status = queued                                                                            ]8;id=320581;file://C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=818357;file://C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\tidy3d\web\webapi.py#321\321]8;;\
# [19:08:59] status = preprocess                                                                        ]8;id=604806;file://C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=592063;file://C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\tidy3d\web\webapi.py#315\315]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [19:09:06] Maximum FlexCredit cost: 9.027. Use 'web.real_cost(task_id)' to get the billed FlexCredit  ]8;id=858085;file://C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=953518;file://C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\tidy3d\web\webapi.py#338\338]8;;\
#            cost after a simulation run.
#            starting up solver                                                                         ]8;id=150716;file://C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=65501;file://C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\tidy3d\web\webapi.py#342\342]8;;\
# [19:09:07] running solver                                                                             ]8;id=887710;file://C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=70276;file://C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\tidy3d\web\webapi.py#352\352]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [19:16:54] status = postprocess                                                                       ]8;id=812812;file://C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=202392;file://C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\tidy3d\web\webapi.py#383\383]8;;\
# [19:16:59] status = success                                                                           ]8;id=948332;file://C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=670638;file://C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\tidy3d\web\webapi.py#390\390]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Billed flex unit cost:  9.026755653410643
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [19:17:09] loading SimulationData from data/cooling.hdf5                                              ]8;id=306280;file://C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=922919;file://C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\tidy3d\web\webapi.py#568\568]8;;\
# [19:17:10] WARNING: Simulation final field decay value of 6.56e-05 is greater than the simulation     ]8;id=323237;file://C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=681552;file://C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\tidy3d\web\webapi.py#575\575]8;;\
#            shutoff threshold of 1e-05. Consider simulation again with large run_time duration for
#            more accurate results.
# Simulation domain Nx, Ny, Nz: [334, 334, 1358]
# Applied symmetries: (0, 0, 0)
# Number of computational grid points: 1.5172e+08.
# Using subpixel averaging: True
# Number of time steps: 1.7510e+05
# Automatic shutoff factor: 1.00e-05
# Time step (s): 5.7112e-17
#
#
# Compute source modes time (s):     1.7912
# Compute monitor modes time (s):    0.0947
# Rest of setup time (s):            16.9861
#
# Running solver for 175097 time steps...
# - Time step     32 / time 1.83e-15s (  0 % done), field decay: 1.00e+00
# - Time step   7003 / time 4.00e-13s (  4 % done), field decay: 3.69e-01
# - Time step  14007 / time 8.00e-13s (  8 % done), field decay: 2.54e-01
# - Time step  21011 / time 1.20e-12s ( 12 % done), field decay: 1.75e-01
# - Time step  28015 / time 1.60e-12s ( 16 % done), field decay: 1.20e-01
# - Time step  35019 / time 2.00e-12s ( 20 % done), field decay: 8.23e-02
# - Time step  42023 / time 2.40e-12s ( 24 % done), field decay: 5.66e-02
# - Time step  49027 / time 2.80e-12s ( 28 % done), field decay: 3.91e-02
# - Time step  56031 / time 3.20e-12s ( 32 % done), field decay: 2.69e-02
# - Time step  63034 / time 3.60e-12s ( 36 % done), field decay: 1.86e-02
# - Time step  70038 / time 4.00e-12s ( 40 % done), field decay: 1.29e-02
# - Time step  77042 / time 4.40e-12s ( 44 % done), field decay: 8.92e-03
# - Time step  84046 / time 4.80e-12s ( 48 % done), field decay: 6.19e-03
# - Time step  91050 / time 5.20e-12s ( 52 % done), field decay: 4.30e-03
# - Time step  98054 / time 5.60e-12s ( 56 % done), field decay: 2.99e-03
# - Time step 105058 / time 6.00e-12s ( 60 % done), field decay: 2.08e-03
# - Time step 112062 / time 6.40e-12s ( 64 % done), field decay: 1.45e-03
# - Time step 119065 / time 6.80e-12s ( 68 % done), field decay: 1.01e-03
# - Time step 126069 / time 7.20e-12s ( 72 % done), field decay: 7.09e-04
# - Time step 133073 / time 7.60e-12s ( 76 % done), field decay: 4.97e-04
# - Time step 140077 / time 8.00e-12s ( 80 % done), field decay: 3.50e-04
# - Time step 147081 / time 8.40e-12s ( 84 % done), field decay: 2.50e-04
# - Time step 154085 / time 8.80e-12s ( 88 % done), field decay: 1.79e-04
# - Time step 161089 / time 9.20e-12s ( 92 % done), field decay: 1.30e-04
# - Time step 168093 / time 9.60e-12s ( 96 % done), field decay: 9.24e-05
# - Time step 175096 / time 1.00e-11s (100 % done), field decay: 6.56e-05
#
# Solver time (s):                   442.8377
# Data write time (s):               0.0590

# %%
#Result Visualization
R = sim_data["R"].flux
T = -sim_data["T"].flux
A = 1 - R - T
plt.plot(td.C_0 /freqs, R, td.C_0 /freqs, T, td.C_0 /freqs, A)
np.savetxt('data/R_0.3-2.5um.txt', (np.transpose((td.C_0 /freqs, R))))

plt.xlabel("Wavelength (μm)")
plt.ylim(0, 1)
plt.legend(("R", "T", "A"))
plt.show()

sim_data.plot_field(field_monitor_name="field", field_name="E", val="abs^2")
plt.show()
