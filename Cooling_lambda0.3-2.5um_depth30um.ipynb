# %%
import numpy as np
import matplotlib.pyplot as plt

import tidy3d as td
import tidy3d.web as web

# %%
# Define Paramters
# radius and location of the sphere
radius_Al2O3 = 0.25
radius_SiO2 = 4 # exp is 6um
box_size_xy = 10
box_size_z = 30

vol_Al2O3 = 4/3 * np.pi * np.power(radius_Al2O3,3)
vol_SiO2 = 4/3 * np.pi * np.power(radius_SiO2,3)
vol_box = box_size_xy * box_size_xy * box_size_z
num_Al2O3 = int(np.floor(0.2 * vol_box / vol_Al2O3))   # 20% of volumn is Al2O3
num_SiO2 = int(np.floor(0.3 * vol_box / vol_SiO2))   # 30% of volumn is SiO2
print('num_Al2O3',num_Al2O3)
print('num_SiO2',num_SiO2)

center = [0, 0, 0]

# permittivity of the Al2O3 sphere 
eps_Al2O3 = 3.0625
eps_SiO2 = 2.1316

# free space central wavelength
wl_start = 0.3  # wavelength
wl_end = 2.5  # wavelength
freq_start = td.C_0 / wl_end
freq_end = td.C_0 / wl_start

freqs = np.linspace(freq_start, freq_end, 100)  # freqeucny range of the simulation
freq0 = (freq_start + freq_end)/2  # central frequency
freqw = freq_end - freq_start  # width of the frequency range
print('freq0:',freq0)

lda0 = td.C_0 / freq0
print('lda0:',lda0)

# distance between the surface of the sphere and the start of the PML layers along each cartesian direction
buffer_PML = 2 * wl_end
buffer_source = 1 * wl_end

# Define material properties
air = td.Medium(permittivity=1)
Al2O3 = td.Medium(permittivity=eps_Al2O3)
SiO2 = td.Medium(permittivity=eps_SiO2)

# resolution control
min_steps_per_wvl = 20

# set the domain size in x, y, and z
domain_size_xy = box_size_xy 
domain_size_z = buffer_PML + box_size_z + buffer_PML

# construct simulation size array
sim_size = (domain_size_xy, domain_size_xy, domain_size_z)
print('sim_size:',sim_size)
# Out:
# num_Al2O3 9167
# num_SiO2 3
# freq0: 559612588266666.7
# lda0: 0.5357142857142857
# sim_size: (10, 10, 40.0)

# %%
# Create random structures
geometry = []
for i in range(num_SiO2):
    position_xy = (box_size_xy - 2*radius_SiO2) * (np.random.rand(2) - 0.5) 
    position_z = (box_size_z - 2*radius_SiO2) * (np.random.rand(1) - 0.5) 
    position = [position_xy[0],position_xy[1],position_z]
    sphere = td.Structure(geometry=td.Sphere(center=position, radius=radius_SiO2), medium=SiO2)
    geometry.append(sphere)
    
for i in range(num_Al2O3):
    position_xy = (box_size_xy - 2*radius_Al2O3) * (np.random.rand(2) - 0.5) 
    position_z = (box_size_z - 2*radius_Al2O3) * (np.random.rand(1) - 0.5)
    position = [position_xy[0],position_xy[1],position_z]
    sphere = td.Structure(geometry=td.Sphere(center=position, radius=radius_Al2O3), medium=Al2O3)
    geometry.append(sphere)    
    
geometry = tuple(geometry)
print('Geometry Finish')
# Out:
# Geometry Finish

# %%
# add a plane wave source
plane_wave = td.PlaneWave(
    source_time=td.GaussianPulse(freq0=freq0, fwidth=0.5 * freqw),
    size=(td.inf, td.inf, 0),
    center=(0, 0, box_size_z/2 + buffer_source),
    direction="-",
    pol_angle=0,
)

# add a flux monitor to detect transmission
monitor_t = td.FluxMonitor(
    center=[0, 0, -box_size_z/2 - (buffer_source+buffer_PML)/2], size=[td.inf, td.inf, 0], freqs=freqs, name="T"
)

# add a flux monitor to detect reflection
monitor_r = td.FluxMonitor(
    center=[0, 0, box_size_z/2 + (buffer_source+buffer_PML)/2], size=[td.inf, td.inf, 0], freqs=freqs, name="R"
)

# add a field monitor to see the field profile at the absorption peak frequency
monitor_field = td.FieldMonitor(
    center=[0, 0, 0], size=[td.inf, 0, box_size_z], freqs=[freq0], name="field"
)

print('Source and Monitor setup Finish')
# Out:
# Source and Monitor setup Finish

# %%
run_time = 1e-11  # simulation run time

# set up simulation
sim = td.Simulation(
    size=sim_size,
#     grid_spec=td.GridSpec.auto(min_steps_per_wvl=min_steps_per_wvl, wavelength=lda0), # Non uniform grip
    grid_spec=td.GridSpec.uniform(dl =lda0/20),
    structures=geometry,
    sources=[plane_wave],
    monitors=[monitor_t, monitor_r, monitor_field],
    run_time=run_time,
    boundary_spec=td.BoundarySpec(
        x=td.Boundary.periodic(), y=td.Boundary.periodic(), z=td.Boundary.pml()
    ), 
#     boundary_spec=td.BoundarySpec.all_sides(boundary=td.PML()),  # PML boundary
)  # symmetry can be used to greatly reduce the computational cost

print('Simulation setup Finish')
# Out:
# Simulation setup Finish

# %%
# Visualize source
plane_wave.source_time.plot(np.linspace(0, run_time/10, 1001))
plt.show()

plane_wave.source_time.plot_spectrum(
    times=np.linspace(0, run_time/10, 2000), val="abs"
)
plt.show()

# %%
cfig, ax = plt.subplots(1, 2, figsize=(7, 3))
sim.plot(y=0, ax=ax[0])
sim.plot(z=0.1, freq=freq0, ax=ax[1])
plt.show()

print('Visualize Source Finish')
# Out:
# Visualize Source Finish

# %%
task_id = web.upload(sim, task_name="Simulation")
# print("Max flex unit cost: ", web.estimate_cost(task_id))
# Out:
# [08:52:45] Created task 'Simulation' with task_id 'fdve-772667e0-c257-4367-91a5-14e6ab395003v1'.      ]8;id=32895;file://C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=36224;file://C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\tidy3d\web\webapi.py#186\186]8;;\
#            View task using web UI at                                                                  ]8;id=618711;file://C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=215654;file://C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\tidy3d\web\webapi.py#188\188]8;;\
#            ]8;id=880305;https://tidy3d.simulation.cloud/workbench?taskId=fdve-772667e0-c257-4367-91a5-14e6ab395003v1\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=254015;https://tidy3d.simulation.cloud/workbench?taskId=fdve-772667e0-c257-4367-91a5-14e6ab395003v1\taskId]8;;\]8;id=880305;https://tidy3d.simulation.cloud/workbench?taskId=fdve-772667e0-c257-4367-91a5-14e6ab395003v1\=]8;;\]8;id=874412;https://tidy3d.simulation.cloud/workbench?taskId=fdve-772667e0-c257-4367-91a5-14e6ab395003v1\fdve]8;;\]8;id=880305;https://tidy3d.simulation.cloud/workbench?taskId=fdve-772667e0-c257-4367-91a5-14e6ab395003v1\-772667e0-c257-4367-91a5-14e6ab39500]8;;\
#            ]8;id=880305;https://tidy3d.simulation.cloud/workbench?taskId=fdve-772667e0-c257-4367-91a5-14e6ab395003v1\3v1']8;;\.
# C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\rich\live.py:229: UserWarning: install "ipywidgets"
# for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
web.start(task_id)
web.monitor(task_id, verbose=True)

import time
time.sleep(4)
print("Billed flex unit cost: ", web.real_cost(task_id))

sim_data = web.load(task_id, path="data/cooling.hdf5")

# Show the output of the log file
print(sim_data.log)


# sim_data = sim.dict_from_hdf5(fname='data/cooling.hdf5')
# # print(sim_data)

# R = sim_data["R"].flux
# print(R)
# Out:
# [08:52:55] status = queued                                                                            ]8;id=905317;file://C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=520692;file://C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\tidy3d\web\webapi.py#321\321]8;;\
# [08:53:02] status = preprocess                                                                        ]8;id=593887;file://C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=852419;file://C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\tidy3d\web\webapi.py#315\315]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [08:53:18] Maximum FlexCredit cost: 12.482. Use 'web.real_cost(task_id)' to get the billed FlexCredit ]8;id=7669;file://C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=905185;file://C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\tidy3d\web\webapi.py#338\338]8;;\
#            cost after a simulation run.
#            starting up solver                                                                         ]8;id=671502;file://C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=161007;file://C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\tidy3d\web\webapi.py#342\342]8;;\
#            running solver                                                                             ]8;id=155678;file://C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=398727;file://C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\tidy3d\web\webapi.py#352\352]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [09:00:36] status = postprocess                                                                       ]8;id=22837;file://C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=798776;file://C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\tidy3d\web\webapi.py#383\383]8;;\
# [09:00:42] status = success                                                                           ]8;id=150574;file://C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=673085;file://C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\tidy3d\web\webapi.py#390\390]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Billed flex unit cost:  12.482426651472732
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [09:00:53] loading SimulationData from data/cooling.hdf5                                              ]8;id=498416;file://C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=330504;file://C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\tidy3d\web\webapi.py#568\568]8;;\
# [09:00:55] WARNING: Simulation final field decay value of 6.15e-05 is greater than the simulation     ]8;id=30918;file://C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\tidy3d\web\webapi.py\webapi.py]8;;\:]8;id=754635;file://C:\Users\54377\AppData\Roaming\Python\Python310\site-packages\tidy3d\web\webapi.py#575\575]8;;\
#            shutoff threshold of 1e-05. Consider simulation again with large run_time duration for
#            more accurate results.
# Simulation domain Nx, Ny, Nz: [374, 374, 1518]
# Applied symmetries: (0, 0, 0)
# Number of computational grid points: 2.1261e+08.
# Using subpixel averaging: True
# Number of time steps: 1.9608e+05
# Automatic shutoff factor: 1.00e-05
# Time step (s): 5.1001e-17
#
#
# Compute source modes time (s):     4.9109
# Compute monitor modes time (s):    0.3086
# Rest of setup time (s):            13.5316
#
# Running solver for 196077 time steps...
# - Time step     35 / time 1.79e-15s (  0 % done), field decay: 1.00e+00
# - Time step   7843 / time 4.00e-13s (  4 % done), field decay: 3.86e-01
# - Time step  15686 / time 8.00e-13s (  8 % done), field decay: 2.58e-01
# - Time step  23529 / time 1.20e-12s ( 12 % done), field decay: 1.75e-01
# - Time step  31372 / time 1.60e-12s ( 16 % done), field decay: 1.19e-01
# - Time step  39215 / time 2.00e-12s ( 20 % done), field decay: 8.18e-02
# - Time step  47058 / time 2.40e-12s ( 24 % done), field decay: 5.61e-02
# - Time step  54901 / time 2.80e-12s ( 28 % done), field decay: 3.86e-02
# - Time step  62744 / time 3.20e-12s ( 32 % done), field decay: 2.65e-02
# - Time step  70587 / time 3.60e-12s ( 36 % done), field decay: 1.83e-02
# - Time step  78430 / time 4.00e-12s ( 40 % done), field decay: 1.26e-02
# - Time step  86273 / time 4.40e-12s ( 44 % done), field decay: 8.75e-03
# - Time step  94116 / time 4.80e-12s ( 48 % done), field decay: 6.05e-03
# - Time step 101960 / time 5.20e-12s ( 52 % done), field decay: 4.19e-03
# - Time step 109803 / time 5.60e-12s ( 56 % done), field decay: 2.91e-03
# - Time step 117646 / time 6.00e-12s ( 60 % done), field decay: 2.02e-03
# - Time step 125489 / time 6.40e-12s ( 64 % done), field decay: 1.41e-03
# - Time step 133332 / time 6.80e-12s ( 68 % done), field decay: 9.79e-04
# - Time step 141175 / time 7.20e-12s ( 72 % done), field decay: 6.84e-04
# - Time step 149018 / time 7.60e-12s ( 76 % done), field decay: 4.76e-04
# - Time step 156861 / time 8.00e-12s ( 80 % done), field decay: 3.34e-04
# - Time step 164704 / time 8.40e-12s ( 84 % done), field decay: 2.34e-04
# - Time step 172547 / time 8.80e-12s ( 88 % done), field decay: 1.65e-04
# - Time step 180390 / time 9.20e-12s ( 92 % done), field decay: 1.18e-04
# - Time step 188233 / time 9.60e-12s ( 96 % done), field decay: 8.28e-05
# - Time step 196076 / time 1.00e-11s (100 % done), field decay: 6.15e-05
#
# Solver time (s):                   416.1794
# Data write time (s):               0.0710

# %%
#Result Visualization
R = sim_data["R"].flux
T = -sim_data["T"].flux
A = 1 - R - T
plt.plot(td.C_0 /freqs, R, td.C_0 /freqs, T, td.C_0 /freqs, A)
np.savetxt('data/R_0.3-2.5um.txt', (np.transpose((td.C_0 /freqs, R))))

plt.xlabel("Wavelength (μm)")
plt.ylim(0, 1)
plt.legend(("R", "T", "A"))
plt.show()

sim_data.plot_field(field_monitor_name="field", field_name="E", val="abs^2")
plt.show()
